# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# --- Data Loading ---
try:
    df1 = pd.read_csv("citation1.csv").iloc[1:, :] #Skip header row
    df2 = pd.read_csv("citation2.csv").iloc[1:, :]  #Skip header row
    df3 = pd.read_csv("citation3.csv").iloc[1:, :]   #Skip header row
# Out:
#   Cell In[2], line 5
#     df3 = pd.read_csv("citation3.csv").iloc[1:, :]   #Skip header row
#                                                                      ^
# _IncompleteInputError: incomplete input
