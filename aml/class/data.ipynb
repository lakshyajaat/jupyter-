# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# /home/lakshya

# %%
df = pd.read_csv('/home/lakshya/jupyter/aml/class/placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in LPA )')
# Out:
# Text(0, 0.5, 'Package(in LPA )')

# %%
from sklearn.model_selection import train_test_split

# %%
part1, part2 = train_test_split(df, test_size=0.5, random_state=42)

# %%
print("Part 1 shape:", part1.shape)
# Out:
# Part 1 shape: (100, 2)

# %%
print("Part 2 shape:", part2.shape)
# Out:
# Part 2 shape: (100, 2)

# %%
plt.plot(df['cgpa'], df['salary'], marker='o', linestyle='-')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ...
